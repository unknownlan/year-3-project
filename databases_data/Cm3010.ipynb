# %% [markdown]
# # CM 3010

# %% [markdown]
# ## 1 Load Datasets

# %%
import numpy as np
import os

# %% [markdown]
# #### load the all dataset and  check the first file called " health expenditure"

# %%
import pandas as pd
# Specify the file path 
file_path_health = 'Health_Expenditure/health.csv'
file_path_working_age = 'Age_Dependency_Working_Age/working.csv'
file_path_youth = 'Age_Dependency_Youth/youth.csv'
file_path_elderly = 'Age_Dependency_Elderly/elderly.csv'

# Read the CSV file, skipping the first 4 rows
df = pd.read_csv(file_path_health, skiprows=4)

# Display the first few rows of the DataFrame to verify the structure
print("First few rows of the health expenditure Dataframe:")
display(df.head())
# Out:
# First few rows of the health expenditure Dataframe:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                           Indicator Name     Indicator Code  1960  1961  1962  \
# 0  Current health expenditure (% of GDP)  SH.XPD.CHEX.GD.ZS   NaN   NaN   NaN
# 1  Current health expenditure (% of GDP)  SH.XPD.CHEX.GD.ZS   NaN   NaN   NaN
# 2  Current health expenditure (% of GDP)  SH.XPD.CHEX.GD.ZS   NaN   NaN   NaN
# 3  Current health expenditure (% of GDP)  SH.XPD.CHEX.GD.ZS   NaN   NaN   NaN
# 4  Current health expenditure (% of GDP)  SH.XPD.CHEX.GD.ZS   NaN   NaN   NaN
#
#    1963  1964  1965  ...       2015       2016       2017       2018  \
# 0   NaN   NaN   NaN  ...        NaN        NaN        NaN        NaN
# ...

# %%
# Check the column names to ensure they are correctly parsed
print("\nColumn names:")
print(df.columns)
# Out:
# Column names:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', 'Unnamed: 68'],
#       dtype='object')

# %%
# Accessing specific columns or years' data
# Adjust column names as needed based on the actual DataFrame structure
years = ['2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']
for year in years:
    if year in df.columns:
        year_data = df[year]
        print(f"\nValue counts for '{year}' column:")
        print(year_data.value_counts())
    else:
        print(f"\n'{year}' column not found in DataFrame.")
# Out:
# Value counts for '2013' column:
# 2013
# 5.097014    2
# 3.567699    2
# 4.965594    2
# 8.870000    1
# 6.125854    1
#            ..
# 8.437964    1
# 5.626529    1
# 5.771889    1
# 3.802313    1
# 7.109403    1
# Name: count, Length: 231, dtype: int64
#
# Value counts for '2014' column:
# 2014
# 7.050000    2
# 3.470834    2
# 5.840839    1
# 8.386758    1
# 5.380247    1
#            ..
# 7.891412    1
# 4.773536    1
# 5.888568    1
# 3.947554    1
# 8.132273    1
# Name: count, Length: 232, dtype: int64
#
# Value counts for '2015' column:
# 2015
# 3.452434    2
# 4.973738    2
# 5.998256    1
# 5.470000    1
# 3.673638    1
#            ..
# 8.220045    1
# 4.646756    1
# 6.006020    1
# 4.022648    1
# 7.449827    1
# Name: count, Length: 232, dtype: int64
#
# Value counts for '2016' column:
# 2016
# 6.367661     2
# 3.384545     2
# 5.041881     2
# 10.060000    1
# 4.580086     1
#             ..
# 2.859417     1
# 8.448747     1
# 4.439100     1
# 6.070082     1
# ...

# %% [markdown]
# #### check the second dataset called "working age "

# %%
# Read the CSV file, skipping the first 4 rows
df_age_dependency = pd.read_csv(file_path_working_age, skiprows=0)

# Display the column names to verify the structure
print("Columns in the Age Dependency DataFrame:")
print(df_age_dependency.columns)

# Display the first few rows of the DataFrame to verify the structure
print("\nFirst few rows of the Age Dependency DataFrame:")
display(df_age_dependency.head())

# Create a mapping dictionary for renaming columns
rename_mapping = {col: col.split(' ')[0] for col in df_age_dependency.columns if 'YR' in col}

# Apply the renaming
df_age_dependency.rename(columns=rename_mapping, inplace=True)

# Verify if specific columns exist
required_columns = ['Country Name', 'Country Code'] + [str(year) for year in range(2013, 2024)]
missing_columns = [col for col in required_columns if col not in df_age_dependency.columns]

if missing_columns:
    print(f"Missing columns: {missing_columns}")
else:
    print("All required columns are present.")

# Display the updated column names to verify the renaming
print("\nUpdated columns in the Age Dependency DataFrame:")
print(df_age_dependency.columns)

# Display the first few rows of the updated DataFrame to verify the structure
print("\nFirst few rows of the updated Age Dependency DataFrame:")
display(df_age_dependency.head())
# Out:
# Columns in the Age Dependency DataFrame:
# Index(['Series Name', 'Series Code', 'Country Name', 'Country Code',
#        '1990 [YR1990]', '2000 [YR2000]', '2014 [YR2014]', '2015 [YR2015]',
#        '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]',
#        '2020 [YR2020]', '2021 [YR2021]', '2022 [YR2022]', '2023 [YR2023]'],
#       dtype='object')
#
# First few rows of the Age Dependency DataFrame:
#                                          Series Name  Series Code  \
# 0  Age dependency ratio (% of working-age populat...  SP.POP.DPND
# 1  Age dependency ratio (% of working-age populat...  SP.POP.DPND
# 2  Age dependency ratio (% of working-age populat...  SP.POP.DPND
# 3  Age dependency ratio (% of working-age populat...  SP.POP.DPND
# 4  Age dependency ratio (% of working-age populat...  SP.POP.DPND
#
#      Country Name Country Code  1990 [YR1990]  2000 [YR2000]  2014 [YR2014]  \
# 0     Afghanistan          AFG      98.890488     108.346635      94.706697
# ...

# %% [markdown]
# #### check the third data called age dependency youth

# %%
# Specify the file path
file_path_youth = 'Age_Dependency_Youth/youth.csv'

# Read the CSV file
df_age_dependency_youth = pd.read_csv(file_path_youth)

# Display the column names to verify the structure
print("Columns in the Youth Age Dependency DataFrame:")
print(df_age_dependency_youth.columns)

# Display the first few rows of the DataFrame to verify the structure
print("\nFirst few rows of the Youth Age Dependency DataFrame:")
display(df_age_dependency_youth.head())

# Create a mapping dictionary for renaming columns
rename_mapping = {col: col.split(' ')[0] for col in df_age_dependency_youth.columns if 'YR' in col}

# Apply the renaming
df_age_dependency_youth.rename(columns=rename_mapping, inplace=True)

# Verify if specific columns exist
required_columns = ['Country Name', 'Country Code'] + [str(year) for year in range(2013, 2024)]
missing_columns = [col for col in required_columns if col not in df_age_dependency_youth.columns]

if missing_columns:
    print(f"Missing columns: {missing_columns}")
else:
    print("All required columns are present.")

# Display the updated column names to verify the renaming
print("\nUpdated columns in the Youth Age Dependency DataFrame:")
print(df_age_dependency_youth.columns)

# Display the first few rows of the updated DataFrame to verify the structure
print("\nFirst few rows of the updated Youth Age Dependency DataFrame:")
display(df_age_dependency_youth.head())
# Out:
# Columns in the Youth Age Dependency DataFrame:
# Index(['Series Name', 'Series Code', 'Country Name', 'Country Code',
#        '1990 [YR1990]', '2000 [YR2000]', '2014 [YR2014]', '2015 [YR2015]',
#        '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]',
#        '2020 [YR2020]', '2021 [YR2021]', '2022 [YR2022]', '2023 [YR2023]'],
#       dtype='object')
#
# First few rows of the Youth Age Dependency DataFrame:
#                                          Series Name     Series Code  \
# 0  Age dependency ratio, young (% of working-age ...  SP.POP.DPND.YG
# 1  Age dependency ratio, young (% of working-age ...  SP.POP.DPND.YG
# 2  Age dependency ratio, young (% of working-age ...  SP.POP.DPND.YG
# 3  Age dependency ratio, young (% of working-age ...  SP.POP.DPND.YG
# 4  Age dependency ratio, young (% of working-age ...  SP.POP.DPND.YG
#
#      Country Name Country Code     1990 [YR1990]     2000 [YR2000]  \
# ...

# %%
#### check the forth data called "age dependency eladerly"

# %%
# Read the CSV file, skipping the first 4 rows
df_age_dependency_elderly = pd.read_csv(file_path_elderly)

# Display the column names to verify the structure
print("Columns in the e Dependency DataFrame:")
print(df_age_dependency_elderly.columns)

# Display the first few rows of the DataFrame to verify the structure
print("\nFirst few rows of the Old Age Dependency DataFrame:")
display(df_age_dependency_elderly.head())

# Create a mapping dictionary for renaming columns
rename_mapping = {col: col.split(' ')[0] for col in df_age_dependency_elderly.columns if 'YR' in col}

# Apply the renaming
df_age_dependency_elderly.rename(columns=rename_mapping, inplace=True)

# Verify if specific columns exist
required_columns = ['Country Name', 'Country Code'] + [str(year) for year in range(2013, 2024)]
missing_columns = [col for col in required_columns if col not in df_age_dependency_elderly.columns]

if missing_columns:
    print(f"Missing columns: {missing_columns}")
else:
    print("All required columns are present.")

# Display the updated column names to verify the renaming
print("\nUpdated columns in the old Age Dependency DataFrame:")
print(df_age_dependency_elderly.columns)

# Display the first few rows of the updated DataFrame to verify the structure
print("\nFirst few rows of the updated Old Age Dependency DataFrame:")
display(df_age_dependency_elderly.head())
# Out:
# Columns in the e Dependency DataFrame:
# Index(['Series Name', 'Series Code', 'Country Name', 'Country Code',
#        '1990 [YR1990]', '2000 [YR2000]', '2013 [YR2013]', '2014 [YR2014]',
#        '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]',
#        '2019 [YR2019]', '2020 [YR2020]', '2021 [YR2021]', '2022 [YR2022]'],
#       dtype='object')
#
# First few rows of the Old Age Dependency DataFrame:
#                  Series Name     Series Code                    Country Name  \
# 0  Age dependency ratio, old  SP.POP.DPND.OL     Africa Eastern and Southern
# 1  Age dependency ratio, old  SP.POP.DPND.OL      Africa Western and Central
# 2  Age dependency ratio, old  SP.POP.DPND.OL                      Arab World
# 3  Age dependency ratio, old  SP.POP.DPND.OL          Caribbean small states
# 4  Age dependency ratio, old  SP.POP.DPND.OL  Central Europe and the Baltics
#
#   Country Code     1990 [YR1990]     2000 [YR2000]     2013 [YR2013]  \
# ...

# %% [markdown]
# ## 2. Processing the Raw data

# %%
# Load the CSV file
file_path = 'World_population/population.csv'
population_df = pd.read_csv(file_path)

population_df = population_df.dropna(subset=['Code'])
population_df = population_df[population_df['Code'].str.strip() != '']

# Filter the DataFrame to keep only the years from 2014 to 2021
filtered_population_df = population_df[(population_df['Year'] >= 2014) & (population_df['Year'] <= 2021)]

# Save the filtered DataFrame to a new CSV file
filtered_csv_path = 'World_population/filtered_population_2014_2021.csv'
filtered_population_df.to_csv(filtered_csv_path, index=False)

print(f"Filtered data saved to {filtered_csv_path}")
# Out:
# Filtered data saved to World_population/filtered_population_2014_2021.csv

# %% [markdown]
# ### 2.1 only selected years are required and drop the unnecessary years

# %%
# Drop columns for years 1960 to 2012
years_to_drop = [str(year) for year in range(1960, 2014)]
df.drop(columns=years_to_drop, inplace=True, errors='ignore')
df.drop(columns='Unnamed: 68', inplace=True, errors='ignore')
df_age_dependency.drop(columns=years_to_drop, inplace=True, errors='ignore')
df_age_dependency_youth.drop(columns=years_to_drop, inplace=True, errors='ignore')
df_age_dependency_elderly.drop(columns=years_to_drop, inplace=True, errors='ignore')

#drop 2023 seperatly
df.drop(columns='2023', inplace=True, errors='ignore')
df_age_dependency.drop(columns='2023', inplace=True, errors='ignore')
df_age_dependency_youth.drop(columns='2023', inplace=True, errors='ignore')
df_age_dependency_elderly.drop(columns='2023', inplace=True, errors='ignore')

# Display the first few rows of the DataFrame to verify the structure
print("First few rows of the DataFrame after cleaning:")
display(df.head())
display(df_age_dependency.head())

# Check the remaining column names
print("\nRemaining column names:")
print(df.columns)
# Out:
# First few rows of the DataFrame after cleaning:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                           Indicator Name     Indicator Code      2014  \
# 0  Current health expenditure (% of GDP)  SH.XPD.CHEX.GD.ZS       NaN
# 1  Current health expenditure (% of GDP)  SH.XPD.CHEX.GD.ZS  5.840839
# 2  Current health expenditure (% of GDP)  SH.XPD.CHEX.GD.ZS  9.528878
# 3  Current health expenditure (% of GDP)  SH.XPD.CHEX.GD.ZS  3.583262
# 4  Current health expenditure (% of GDP)  SH.XPD.CHEX.GD.ZS  2.434129
#
#         2015       2016       2017       2018       2019       2020  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1   5.998256   6.098205   5.954076   5.809503   5.830176   5.881698
# ...

# %%
display(df_age_dependency_youth.head())
display(df_age_dependency_elderly.head())
# Out:
#                                          Series Name     Series Code  \
# 0  Age dependency ratio, young (% of working-age ...  SP.POP.DPND.YG
# 1  Age dependency ratio, young (% of working-age ...  SP.POP.DPND.YG
# 2  Age dependency ratio, young (% of working-age ...  SP.POP.DPND.YG
# 3  Age dependency ratio, young (% of working-age ...  SP.POP.DPND.YG
# 4  Age dependency ratio, young (% of working-age ...  SP.POP.DPND.YG
#
#      Country Name Country Code              2014              2015  \
# 0     Afghanistan          AFG  90.0159003100492  88.3982020260321
# 1         Albania          ALB  27.2542318244552  26.5983978791543
# 2         Algeria          DZA  43.0501410944391  44.0738078725369
# 3  American Samoa          ASM  50.7529618519528  49.5619677755315
# 4         Andorra          AND  22.1515057435579  21.5599620088775
#
#                2016              2017              2018              2019  \
# ...

# %% [markdown]
# From the data shown above, we can see that for certain data only 2014 data onwards available. At the same time, the data for health expenditure in 2022 and onwards is missing. Hence we only take all the database from 2014 to 2021.

# %% [markdown]
# ### check for missing value

# %%
# Clean and Check for missing values
df = df.replace({np.nan: 0})
missing_values = df.isnull().sum()
print("\nMissing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 2014              0
# 2015              0
# 2016              0
# 2017              0
# 2018              0
# 2019              0
# 2020              0
# 2021              0
# 2022              0
# dtype: int64

# %%
# Function to process the dataframes
def process_dataframe(data, skiprows):
    # Read the CSV file
    df = data
    
    df = df.replace({np.nan: 0})
    
    # Check for missing values
    missing_values = df.isnull().sum()
    print(missing_values)
    
    # Drop rows with any missing values
    df_cleaned = df.dropna()
    
    # Display the first few rows of the DataFrame to verify the structure
    #print(f"\nFirst few rows of the DataFrame after dropping rows with missing values for {file_path}:")
    display(df_cleaned.head())
    
    return df_cleaned

# Process each dataframe
df_health_cleaned = process_dataframe(df, skiprows=0)
df_working_age_cleaned = process_dataframe(df_age_dependency, skiprows=0)
df_youth_cleaned = process_dataframe(df_age_dependency_youth, skiprows=0)
df_elderly_cleaned = process_dataframe(df_age_dependency_elderly, skiprows=0)

# Check the remaining column names for each DataFrame
print("\nRemaining column names in the health expenditure DataFrame:")
print(df_health_cleaned.columns)

print("\nRemaining column names in the age dependency working age DataFrame:")
print(df_working_age_cleaned.columns)

print("\nRemaining column names in the age dependency youth DataFrame:")
print(df_youth_cleaned.columns)

print("\nRemaining column names in the age dependency elderly DataFrame:")
print(df_elderly_cleaned.columns)
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 2014              0
# 2015              0
# 2016              0
# 2017              0
# 2018              0
# 2019              0
# 2020              0
# 2021              0
# 2022              0
# dtype: int64
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                           Indicator Name     Indicator Code      2014  \
# 0  Current health expenditure (% of GDP)  SH.XPD.CHEX.GD.ZS  0.000000
# 1  Current health expenditure (% of GDP)  SH.XPD.CHEX.GD.ZS  5.840839
# 2  Current health expenditure (% of GDP)  SH.XPD.CHEX.GD.ZS  9.528878
# 3  Current health expenditure (% of GDP)  SH.XPD.CHEX.GD.ZS  3.583262
# ...

# %% [markdown]
# ## 3. setup MySQL environment

# %%
# check MySQL service status
# !brew services list
# Out:
# Name  Status  User         File
# mysql started tlanchaokeai ~/Library/LaunchAgents/homebrew.mxcl.mysql.plist

# %%
pip install sqlalchemy==2.0.20
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# install sql magic, required for running sql commands in jupyter notebook

# %%
pip install ipython-sql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # enable sql magic in the notebook
# %reload_ext sql
# # queries are returned in the pandas format
# %config SqlMagic.autopandas=True

# %% [markdown]
# pip install mysql-connector-python ipython-sql

# %%
# %load_ext sql
database_url = "sqlite:///HealthAgeComparisonDB.db"
# %sql $database_url

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS HealthExpenditure (
#     country TEXT,
#     year INTEGER,
#     expenditure_percent_gdp REAL
# );
#
# CREATE TABLE IF NOT EXISTS AgeDependency (
#     country TEXT,
#     year INTEGER,
#     dependency_ratio REAL
# );
# Out:
#  * sqlite:///HealthAgeComparisonDB.db
# Done.
# Done.
# []

# %% [markdown]
# # project name
# os.environ["PROJECT_NAME"] = "HealthAgeData"
# # database name
# os.environ["DATABASE_NAME"] = os.getenv("Health_expenditure")
#
#
# # mysql credentials
# os.environ["MYSQL_USER"] = "SG"
# os.environ["MYSQL_USER_PASSWORD"] = "SG_health"

# %% [markdown]
# # Import required modules
# import os
# import sqlite3
# from sqlalchemy import create_engine
#
# # Set environment variables
# os.environ["PROJECT_NAME"] = "HealthAgeComparison"
# os.environ["DATABASE_NAME"] = "HealthAgeComparisonDB.db"
#
# # Load the SQL extension
# %load_ext sql
#
# # Connect to the SQLite database
# database_url = f"sqlite:///{os.getenv('DATABASE_NAME')}"
# %sql $database_url
#
# # Create tables and insert data
# %%sql
# CREATE TABLE IF NOT EXISTS HealthExpenditure (
#     country TEXT,
#     year INTEGER,
#     expenditure_percent_gdp REAL
# );
#
# CREATE TABLE IF NOT EXISTS AgeDependency (
#     country TEXT,
#     year INTEGER,
#     dependency_ratio REAL
# );
#
# -- Example of inserting data into HealthExpenditure
# INSERT INTO HealthExpenditure (country, year, expenditure_percent_gdp) VALUES
# ('CountryA', 2020, 7.5),
# ('CountryB', 2020, 6.8);
#
# -- Example of inserting data into AgeDependency
# INSERT INTO AgeDependency (country, year, dependency_ratio) VALUES
# ('CountryA', 2020, 55.4),
# ('CountryB', 2020, 47.2);
#
# # Query the tables to see the data
# %%sql
# SELECT * FROM HealthExpenditure;
#
# SELECT * FROM AgeDependency;
